# %%
from tabula import read_pdf

# %%
df = read_pdf("max_temp_la_daily2018.pdf")
df
# Out:
#    Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         Day        Jan         NaN        Feb        NaN
# 1           1         71      2018.0         79       2018
# 2           2         78      2018.0         84       2018
# 3           3         74      2018.0         80       2018
# 4           4         75      2018.0         81       2018
# 5           5         73      2018.0         77       2018
# 6           6         68      2018.0         73       2018
# 7           7         74      2018.0         82       2018
# 8           8         68      2018.0         83       2018
# 9           9         64      2018.0         73       2018
# 10         10         66      2018.0         65       2018
# 11         11         70      2018.0         72       2018
# 12         12         72      2018.0         63       2018
# 13         13         84      2018.0         66       2018
# 14         14         83      2018.0         69       2018
# ...

# %%
help(read_pdf)
# Out:
# Help on function read_pdf in module tabula.wrapper:
#
# read_pdf(input_path, output_format='dataframe', encoding='utf-8', java_options=None, pandas_options=None, multiple_tables=False, **kwargs)
#     Read tables in PDF.
#
#     Args:
#         input_path (file like obj):
#             File like object of tareget PDF file.
#         output_format (str, optional):
#             Output format of this function (dataframe or json)
#         encoding (str, optional):
#             Encoding type for pandas. Default is 'utf-8'
#         java_options (list, optional):
#             Set java options like `-Xmx256m`.
#         pandas_options (dict, optional):
#             Set pandas options like {'header': None}.
#         multiple_tables (bool, optional):
#             This is experimental option. It enables to handle multple tables within a page.
#             Note: If `multiple_tables` option is enabled, tabula-py uses not `pd.read_csv()`,
# ...

# %%
who
# Out:
# Interactive namespace is empty.

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
temp = pd.read_csv("data/fluGT_US_health_10_14_weekly_tmp.csv",header=None)
temp.head()
# Out:
#         0
# 0  12.831
# 1  13.442
# 2  15.275
# 3  13.442
# 4  12.831

# %%
temp2=temp.round()

# %%
temp2.head()
# Out:
#       0
# 0  13.0
# 1  13.0
# 2  15.0
# 3  13.0
# 4  13.0

# %%
temp2.to_csv("fluGT_US_health_10_14_weekly_tmp_rounded.csv",index=False)

# %%
df.to_csv("max_temp_la_daily2018.csv")

# %%
df
# Out:
#    Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         Day        Jan         NaN        Feb        NaN
# 1           1         71      2018.0         79       2018
# 2           2         78      2018.0         84       2018
# 3           3         74      2018.0         80       2018
# 4           4         75      2018.0         81       2018
# 5           5         73      2018.0         77       2018
# 6           6         68      2018.0         73       2018
# 7           7         74      2018.0         82       2018
# 8           8         68      2018.0         83       2018
# 9           9         64      2018.0         73       2018
# 10         10         66      2018.0         65       2018
# 11         11         70      2018.0         72       2018
# 12         12         72      2018.0         63       2018
# 13         13         84      2018.0         66       2018
# 14         14         83      2018.0         69       2018
# ...

# %%
y_orig = pd.read_csv("data/usflu_weekly_10-19.csv")
y_orig.shape
# Out:
# (436, 15)

# %%
y_orig.head()
# Out:
#   REGION TYPE REGION  YEAR  WEEK  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  \
# 0    National      X  2010    40         1.10939          1.13505     2627
# 1    National      X  2010    41         1.24341          1.25256     2953
# 2    National      X  2010    42         1.25726          1.24570     3044
# 3    National      X  2010    43         1.25734          1.26774     3226
# 4    National      X  2010    44         1.43414          1.43723     3451
#
#    AGE 25-49  AGE 25-64  AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  \
# 0       1677        NaN      3142        627     400      8473
# 1       1779        NaN      3522        649     444      9347
# 2       1898        NaN      3641        690     411      9684
# 3       1754        NaN      3822        682     420      9904
# 4       1981        NaN      4397        736     455     11020
#
#    NUM. OF PROVIDERS  TOTAL PATIENTS
# 0               1838          746485
# 1               1875          746230
# ...

# %%
y15_19_orig = y_orig.loc[y_orig['YEAR']>=2015]

# %%
y15_19_orig.head()
# Out:
#     REGION TYPE REGION  YEAR  WEEK  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  \
# 222    National      X  2015     1         4.21374          4.07898     7160
# 223    National      X  2015     2         4.21022          3.93762     7044
# 224    National      X  2015     3         4.25968          4.15076     7840
# 225    National      X  2015     4         3.97761          3.87899     7118
# 226    National      X  2015     5         3.63443          3.45794     6656
#
#      AGE 25-49  AGE 25-64  AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  \
# 222       8072        NaN      9589       3614    3048     31483
# 223       6946        NaN     11966       2909    2339     31204
# 224       6451        NaN     13949       2951    2030     33221
# 225       5844        NaN     13159       2585    1915     30621
# 226       5380        NaN     12093       2368    1654     28151
#
#      NUM. OF PROVIDERS  TOTAL PATIENTS
# 222               1958          771835
# ...

# %%
who
# Out:
# df	 pd	 read_pdf	 temp	 temp2	 y15_19_orig	 y_orig

# %%
y15_19_orig = pd.read_csv("data/usflu_weekly_final_15_19.csv")
y15_19_orig.shape
# Out:
# (175, 3)

# %%
y = y15_19_orig[:,3]
y.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-b763f6e5cf83> in <module>
# ----> 1 y = y15_19_orig[:,3]
#       2 y.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2485         """Return the cached item, item represents a label indexer."""
# ...

# %%
y15_19_orig.head()
# Out:
#    YEAR  WEEK  % WEIGHTED ILI
# 0  2015    40         1.22559
# 1  2015    41         1.31066
# 2  2015    42         1.37110
# 3  2015    43         1.39171
# 4  2015    44         1.43712

# %%
y=y15_19_orig['% WEIGHTED ILI']

# %%
y.shape
# Out:
# (175,)

# %%
X15_19_orig=pd.read_csv("data/fluGT_Viral_US_final_15_19.csv")
X15_19_orig.shape
# Out:
# (175, 5)

# %%
X15_19_orig.head()
# Out:
#          Week  influenza  YEAR  WEEK  PERCENT POSITIVE
# 0   10/4/2015         16  2015    40          7.199298
# 1  10/11/2015         15  2015    41          5.034722
# 2  10/18/2015         13  2015    42          6.176962
# 3  10/25/2015         13  2015    43          4.662379
# 4   11/1/2015         12  2015    44          3.071672

# %%
X = X15_19_orig[['influenza','PERCENT POSITIVE']]
X.shape
# Out:
# (175, 2)

# %%
X.head()
# Out:
#    influenza  PERCENT POSITIVE
# 0         16          7.199298
# 1         15          5.034722
# 2         13          6.176962
# 3         13          4.662379
# 4         12          3.071672

# %%
y.head()
# Out:
# 0    1.22559
# 1    1.31066
# 2    1.37110
# 3    1.39171
# 4    1.43712
# Name: % WEIGHTED ILI, dtype: float64

# %%
X_train = X.head(n=156)
X_test = X.tail(n=19)
y_train = y.head(n=156)
y_test = y.tail(n=19)
X_train.shape
# Out:
# (156, 2)

# %%
y_train.shape
# Out:
# (156,)

# %%
y_test.shape
# Out:
# (19,)

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
forest = RandomForestRegressor().fit(X_train,y_train)
print(forest.score(X_train,y_train))
print(forest.score(X_test,y_test))
# Out:
# 0.989438477065742
# 0.8634783925993623
# C:\Users\guowc_000\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
forest = RandomForestRegressor(max_depth=3, n_estimators=50, random_state=1).fit(X_train,y_train)
print(forest.score(X_train,y_train))
print(forest.score(X_test,y_test))
y_pred = forest.predict(X_test)
y_pred_pd = pd.DataFrame(y_pred)
y_pred_pd.to_csv("y15_19_pred.csv")
# Out:
# 0.9656614447544949
# 0.8364027859651101
